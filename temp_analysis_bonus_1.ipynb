# %% [markdown]
# # Bonus: Temperature Analysis I

# %%
import pandas as pd
from datetime import datetime as dt

# %%
# "tobs" is "temperature observations"
df = pd.read_csv('hawaii_measurements.csv')
df.head()
# Out:
#        station        date  prcp  tobs
# 0  USC00519397  2010-01-01  0.08    65
# 1  USC00519397  2010-01-02  0.00    63
# 2  USC00519397  2010-01-03  0.00    74
# 3  USC00519397  2010-01-04  0.00    76
# 4  USC00519397  2010-01-06   NaN    73

# %%
df.dtypes
# Out:
# station     object
# date        object
# prcp       float64
# tobs         int64
# dtype: object

# %%
df.dropna(how='any')
# Out:
#            station        date  prcp  tobs
# 0      USC00519397  2010-01-01  0.08    65
# 1      USC00519397  2010-01-02  0.00    63
# 2      USC00519397  2010-01-03  0.00    74
# 3      USC00519397  2010-01-04  0.00    76
# 5      USC00519397  2010-01-07  0.06    70
# ...            ...         ...   ...   ...
# 19543  USC00516128  2017-08-17  0.13    72
# 19545  USC00516128  2017-08-19  0.09    71
# 19547  USC00516128  2017-08-21  0.56    76
# 19548  USC00516128  2017-08-22  0.50    76
# 19549  USC00516128  2017-08-23  0.45    76
#
# [18103 rows x 4 columns]

# %%
# Convert the date column format from string to datetime
df['date'] = pd.to_datetime(df['date'])

# %%
df.dtypes
# Out:
# station            object
# date       datetime64[ns]
# prcp              float64
# tobs                int64
# dtype: object

# %%
# Set the date column as the DataFrame index
# Drop the date column
df.set_index('date', drop=True)
# Out:
#                 station  prcp  tobs
# date
# 2010-01-01  USC00519397  0.08    65
# 2010-01-02  USC00519397  0.00    63
# 2010-01-03  USC00519397  0.00    74
# 2010-01-04  USC00519397  0.00    76
# 2010-01-06  USC00519397   NaN    73
# ...                 ...   ...   ...
# 2017-08-19  USC00516128  0.09    71
# 2017-08-20  USC00516128   NaN    78
# 2017-08-21  USC00516128  0.56    76
# 2017-08-22  USC00516128  0.50    76
# 2017-08-23  USC00516128  0.45    76
#
# [19550 rows x 3 columns]

# %%
df
# Out:
#            station       date  prcp  tobs
# 0      USC00519397 2010-01-01  0.08    65
# 1      USC00519397 2010-01-02  0.00    63
# 2      USC00519397 2010-01-03  0.00    74
# 3      USC00519397 2010-01-04  0.00    76
# 4      USC00519397 2010-01-06   NaN    73
# ...            ...        ...   ...   ...
# 19545  USC00516128 2017-08-19  0.09    71
# 19546  USC00516128 2017-08-20   NaN    78
# 19547  USC00516128 2017-08-21  0.56    76
# 19548  USC00516128 2017-08-22  0.50    76
# 19549  USC00516128 2017-08-23  0.45    76
#
# [19550 rows x 4 columns]

# %% [markdown]
# ### Compare June and December data across all years

# %%
from scipy import stats

# %%
# https://stackoverflow.com/questions/25873772/how-to-filter-a-dataframe-of-dates-by-a-particular-month-day

june_df = df[df['date'].dt.month == 6]
june_df
# Out:
#            station       date  prcp  tobs
# 133    USC00519397 2010-06-01  0.00    78
# 134    USC00519397 2010-06-02  0.01    76
# 135    USC00519397 2010-06-03  0.00    78
# 136    USC00519397 2010-06-04  0.00    76
# 137    USC00519397 2010-06-05  0.00    77
# ...            ...        ...   ...   ...
# 19492  USC00516128 2017-06-26  0.02    79
# 19493  USC00516128 2017-06-27  0.10    74
# 19494  USC00516128 2017-06-28  0.02    74
# 19495  USC00516128 2017-06-29  0.04    76
# 19496  USC00516128 2017-06-30  0.20    75
#
# [1700 rows x 4 columns]

# %%
# Filter data for desired months
df.loc[dt(year=2017,month=6,day=1):dt(year=2017,month=6,day=30)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: datetime.datetime(2017, 6, 1, 0, 0)
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_slice_bound(self, label, side, kind)
#    4840         try:
# -> 4841             slc = self.get_loc(label)
#    4842         except KeyError as err:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     352                 raise KeyError(key)
# --> 353         return super().get_loc(key, method=method, tolerance=tolerance)
#     354
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: datetime.datetime(2017, 6, 1, 0, 0)
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-f7289eb927dc> in <module>
#       1 # Filter data for desired months
# ----> 2 df.loc[dt(year=2017,month=6,day=1):dt(year=2017,month=6,day=30)]
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1766
#    1767             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1768             return self._getitem_axis(maybe_callable, axis=axis)
#    1769
#    1770     def _is_scalar_access(self, key: Tuple):
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1910         if isinstance(key, slice):
#    1911             self._validate_key(key, axis)
# -> 1912             return self._get_slice_axis(key, axis=axis)
#    1913         elif com.is_bool_indexer(key):
#    1914             return self._getbool_axis(key, axis=axis)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/indexing.py in _get_slice_axis(self, slice_obj, axis)
#    1795         labels = obj._get_axis(axis)
#    1796         indexer = labels.slice_indexer(
# -> 1797             slice_obj.start, slice_obj.stop, slice_obj.step, kind=self.name
#    1798         )
#    1799
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/indexes/base.py in slice_indexer(self, start, end, step, kind)
#    4710         slice(1, 3)
#    4711         """
# -> 4712         start_slice, end_slice = self.slice_locs(start, end, step=step, kind=kind)
#    4713
#    4714         # return a slice
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/indexes/base.py in slice_locs(self, start, end, step, kind)
#    4923         start_slice = None
#    4924         if start is not None:
# -> 4925             start_slice = self.get_slice_bound(start, "left", kind)
#    4926         if start_slice is None:
#    4927             start_slice = 0
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_slice_bound(self, label, side, kind)
#    4842         except KeyError as err:
#    4843             try:
# -> 4844                 return self._searchsorted_monotonic(label, side)
#    4845             except ValueError:
#    4846                 # raise the original KeyError
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/indexes/base.py in _searchsorted_monotonic(self, label, side)
#    4793     def _searchsorted_monotonic(self, label, side="left"):
#    4794         if self.is_monotonic_increasing:
# -> 4795             return self.searchsorted(label, side=side)
#    4796         elif self.is_monotonic_decreasing:
#    4797             # np.searchsorted expects ascending sort order, have to reverse
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/base.py in searchsorted(self, value, side, sorter)
#    1467     @Appender(_shared_docs["searchsorted"])
#    1468     def searchsorted(self, value, side="left", sorter=None):
# -> 1469         return algorithms.searchsorted(self._values, value, side=side, sorter=sorter)
#    1470
#    1471     def drop_duplicates(self, keep="first", inplace=False):
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/algorithms.py in searchsorted(arr, value, side, sorter)
#    1809             value = value.to_datetime64()
#    1810
# -> 1811     result = arr.searchsorted(value, side=side, sorter=sorter)
#    1812     return result
#    1813
#
# TypeError: '<' not supported between instances of 'int' and 'datetime.datetime'

# %%
df.dtypes

# %%
# Identify the average temperature for June

# %%
# Identify the average temperature for December

# %%
# Create collections of temperature data

# %%
# Run paired t-test

# %% [markdown]
# ### Analysis
